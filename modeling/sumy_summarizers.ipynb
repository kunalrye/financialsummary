# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lex_rank import LexRankSummarizer
from sumy.summarizers.luhn import LuhnSummarizer
from sumy.summarizers.lsa import LsaSummarizer
from sumy.summarizers.edmundson import EdmundsonSummarizer
from sumy.summarizers.text_rank import TextRankSummarizer
from sumy.summarizers.sum_basic import SumBasicSummarizer
from sumy.summarizers.kl import KLSummarizer
from sumy.summarizers.reduction import ReductionSummarizer

from modeling.run_model import summarize_train_docs, summarize_test_docs

# %%
def LexRankSummary(document, sentences):
    parser = PlaintextParser.from_string(document,Tokenizer("english"))
    summarizer = LexRankSummarizer()
    summary = summarizer(parser.document, sentences)
    results = []
    for sentence in summary:
        results.append(str(sentence))
    return results

def LuhnSummary(document, sentences):
    parser = PlaintextParser.from_string(document,Tokenizer("english"))
    summarizer = LuhnSummarizer()
    summary = summarizer(parser.document, sentences)
    results = []
    for sentence in summary:
        results.append(str(sentence))
    return results

def LsaSummary(document, sentences):
    parser = PlaintextParser.from_string(document,Tokenizer("english"))
    summarizer = LsaSummarizer()
    summary = summarizer(parser.document, sentences)
    results = []
    for sentence in summary:
        results.append(str(sentence))
    return results

def EdmundsonSummary(document, sentences):
    parser = PlaintextParser.from_string(document,Tokenizer("english"))
    summarizer = EdmundsonSummarizer()
    summary = summarizer(parser.document, sentences)
    results = []
    for sentence in summary:
        results.append(str(sentence))
    return results

def TextRankSummary(document, sentences):
    parser = PlaintextParser.from_string(document,Tokenizer("english"))
    summarizer = TextRankSummarizer()
    summary = summarizer(parser.document, sentences)
    results = []
    for sentence in summary:
        results.append(str(sentence))
    return results

def SumBasicSummary(document, sentences):
    parser = PlaintextParser.from_string(document,Tokenizer("english"))
    summarizer = SumBasicSummarizer()
    summary = summarizer(parser.document, sentences)
    results = []
    for sentence in summary:
        results.append(str(sentence))
    return results

def KLSummary(document, sentences):
    parser = PlaintextParser.from_string(document,Tokenizer("english"))
    summarizer = KLSummarizer()
    summary = summarizer(parser.document, sentences)
    results = []
    for sentence in summary:
        results.append(str(sentence))
    return results

def ReductionSummary(document, sentences):
    parser = PlaintextParser.from_string(document,Tokenizer("english"))
    summarizer = ReductionSummarizer()
    summary = summarizer(parser.document, sentences)
    results = []
    for sentence in summary:
        results.append(str(sentence))
    return results

# %%
# run these functions for every possible train/test 10q
summarize_train_docs(LexRankSummary, "LexRank")
print("\n")
summarize_train_docs(LuhnSummary, "Lunh")
print("\n")
summarize_train_docs(LsaSummary, "LSA")
print("\n")
summarize_train_docs(EdmundsonSummary, "Edmundson")
print("\n")
summarize_train_docs(TextRankSummary, "TextRank")
print("\n")
summarize_train_docs(SumBasicSummary, "SumBasic")
print("\n")
summarize_train_docs(KLSummary, "KL")
print("\n")
summarize_train_docs(ReductionSummary, "Reduction")
print("\n")

summarize_test_docs(LexRankSummary, "LexRank")
print("\n")
summarize_test_docs(LuhnSummary, "Lunh")
print("\n")
summarize_test_docs(LsaSummary, "LSA")
print("\n")
summarize_test_docs(EdmundsonSummary, "Edmundson")
print("\n")
summarize_test_docs(TextRankSummary, "TextRank")
print("\n")
summarize_test_docs(SumBasicSummary, "SumBasic")
print("\n")
summarize_test_docs(KLSummary, "KL")
print("\n")
summarize_test_docs(ReductionSummary, "Reduction")
# Out:
# defaultdict(<class 'dict'>, {'ADI_0000006281_20180505': {'fls.txt': 0, 'item1.txt': 16, 'item2.txt': 6, 'item3.txt': 0, 'item4.txt': 30, 'part2.txt': 7}, 'ADI_0000006281_20180804': {'fls.txt': 0, 'item1.txt': 16, 'item2.txt': 6, 'item3.txt': 0, 'item4.txt': 30, 'part2.txt': 7}, 'ADI_0000006281_20190202': {'fls.txt': 0, 'item1.txt': 16, 'item2.txt': 5, 'item3.txt': 0, 'item4.txt': 30, 'part2.txt': 8}, 'ADI_0000006281_20190504': {'fls.txt': 0, 'item1.txt': 16, 'item2.txt': 5, 'item3.txt': 0, 'item4.txt': 30, 'part2.txt': 8}, 'ADI_0000006281_20190803': {'fls.txt': 0, 'item1.txt': 16, 'item2.txt': 5, 'item3.txt': 0, 'item4.txt': 30, 'part2.txt': 8}, 'ALOT_0000008146_20180428': {'fls.txt': 0, 'item1.txt': 20, 'item2.txt': 7, 'item3.txt': 30, 'item4.txt': 0, 'part2.txt': 1}, 'ALOT_0000008146_20180728': {'fls.txt': 0, 'item1.txt': 18, 'item2.txt': 9, 'item3.txt': 30, 'item4.txt': 0, 'part2.txt': 2}, 'ALOT_0000008146_20181027': {'fls.txt': 0, 'item1.txt': 20, 'item2.txt': 8, 'item3.txt': 30,
# ...

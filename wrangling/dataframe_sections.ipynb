# %%
from sep_sections import *

# %%
replace('/Users/kunal/Desktop/test')
x = separate_document('/Users/kunal/Desktop/test')
nested_dict_to_txt(x,"/Users/kunal/Desktop/test/")

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS


def random_color_func(word=None, font_size=None, position=None, orientation=None, font_path=None, random_state=None):
    h = 150 #int(360.0 * 45.0 / 255.0)
    s = 100 #int(100.0 * 255.0 / 255.0)
    l = int(100.0 * float(random_state.randint(50, 80)) / 255.0)

    return "hsl({}, {}%, {}%)".format(h, s, l)

file_content=open ("/Users/kunal/Documents/DSCI400/appleriskfactors.txt").read()

wordcloud = WordCloud(
                            stopwords = STOPWORDS,
                            background_color = 'white',
                            width = 1200,
                            height = 1000,
                            color_func = None
                            ).generate(file_content)

plt.figure( figsize=(20,10) )
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
file_content=open ("/Users/kunal/Documents/DSCI400/applewordcloud.txt").read()

wordcloud = WordCloud(
                            stopwords = STOPWORDS,
                            background_color = 'white',
                            width = 1200,
                            height = 1000,
                            color_func = None
                            ).generate(file_content)

plt.figure( figsize=(20,10) )
plt.imshow(wordcloud)
plt.axis('off')
# plt.title('Management Discussion and Analysis')
plt.show()

# %%
x = list(range(1,8))
print(x)
# Out:
# [1, 2, 3, 4, 5, 6, 7]
